# %%
from qiskit import QuantumCircuit, transpile, Aer, assemble, execute
from qiskit.visualization import array_to_latex
from qiskit.visualization import plot_bloch_multivector
import numpy as np

# %%
qc = QuantumCircuit(2)
qc.y(0)
theta = 30  # Angle in degrees
theta_radians = np.deg2rad(theta)
qc.rx(theta_radians, 0)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = assemble(transpile(qc, simulator))
result = simulator.run(job).result()
statevector = result.get_statevector()

# Visualize the state vector of the circuit
print("\nFinal State Vector:")
print(statevector)

# Plot the state vector on the Bloch sphere
plot_bloch_multivector(statevector)
# Out:
# /var/folders/0s/wm9v8tmn6hl16w62yq_hh19h0000gn/T/ipykernel_35851/1354017500.py:3: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = simulator.run(job).result()
# Final State Vector:
# Statevector([2.58819045e-01+0.j        , 5.91458986e-17+0.96592583j,
#              0.00000000e+00+0.j        , 0.00000000e+00+0.j        ],
#             dims=(2, 2))

# %%
#Implementing Swapping

qc.cx(0,1)
qc.cx(1,0)
qc.cx(0,1)
qc.draw()
# Out:
#      ┌───┐┌─────────┐     ┌───┐
# q_0: ┤ Y ├┤ Rx(π/6) ├──■──┤ X ├──■──
#      └───┘└─────────┘┌─┴─┐└─┬─┘┌─┴─┐
# q_1: ────────────────┤ X ├──■──┤ X ├
#                      └───┘     └───┘

# %%
simulator = Aer.get_backend('statevector_simulator')
job = assemble(transpile(qc, simulator))
result = simulator.run(job).result()
statevector = result.get_statevector()

# Visualize the state vector of the circuit
print("\nFinal State Vector:")
print(statevector)

# Plot the state vector on the Bloch sphere
plot_bloch_multivector(statevector)
# Out:
# /var/folders/0s/wm9v8tmn6hl16w62yq_hh19h0000gn/T/ipykernel_35851/1354017500.py:3: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = simulator.run(job).result()
# Final State Vector:
# Statevector([2.58819045e-01+0.j        , 0.00000000e+00+0.j        ,
#              5.91458986e-17+0.96592583j, 0.00000000e+00+0.j        ],
#             dims=(2, 2))

# %%
qc = QuantumCircuit(3)
a = input()
b = input()
c = input()
if a == '1':
    qc.x(0)
if b == '1':
    qc.x(1)
if c == '1':
    qc.x(2)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = assemble(transpile(qc, simulator))
result = simulator.run(job).result()
statevector = result.get_statevector()

# Visualize the state vector of the circuit
print("\nFinal State Vector:")
print(statevector)
array_to_latex(statevector, prefix="\\text{Statevector = }")
# Out:
# Final State Vector:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              1.+0.j],
#             dims=(2, 2, 2))
# /var/folders/0s/wm9v8tmn6hl16w62yq_hh19h0000gn/T/ipykernel_35851/320873138.py:3: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = simulator.run(job).result()
# $$
# \text{Statevector = }
# \begin{bmatrix}
# 0 & 0 & 0 & 0 & 0 & 0 & 0 & 1  \\
#  \end{bmatrix}
# $$

# %%
qc.ccx(0, 1, 2)
qc.cx(0, 1)
qc.x(0)
qc.draw()
# Out:
#      ┌───┐          ┌───┐
# q_0: ┤ X ├──■────■──┤ X ├
#      ├───┤  │  ┌─┴─┐└───┘
# q_1: ┤ X ├──■──┤ X ├─────
#      ├───┤┌─┴─┐└───┘
# q_2: ┤ X ├┤ X ├──────────
#      └───┘└───┘

# %%
simulator = Aer.get_backend('statevector_simulator')
job = assemble(transpile(qc, simulator))
result = simulator.run(job).result()
statevector = result.get_statevector()

# Visualize the state vector of the circuit
print("\nFinal State Vector:")
print(statevector)
array_to_latex(statevector, prefix="\\text{Statevector = }")
# Out:
# Final State Vector:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# /var/folders/0s/wm9v8tmn6hl16w62yq_hh19h0000gn/T/ipykernel_35851/320873138.py:3: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = simulator.run(job).result()
# $$
# \text{Statevector = }
# \begin{bmatrix}
# 1 & 0 & 0 & 0 & 0 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
qc = QuantumCircuit(5, 5)
a = input()
b = input()
c = input()
if a == '1':
    qc.x(0)
if b == '1':
    qc.x(1)
if c == '1':
    qc.x(2)

# %%
for i in range(3):
    qc.ccx(i, 3, 4)
    qc.cx(i, 3)
qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├──■────■──────────────────────
#      └───┘  │    │
# q_1: ───────┼────┼────■────■────────────
#      ┌───┐  │    │    │    │
# q_2: ┤ X ├──┼────┼────┼────┼────■────■──
#      └───┘  │  ┌─┴─┐  │  ┌─┴─┐  │  ┌─┴─┐
# q_3: ───────■──┤ X ├──■──┤ X ├──■──┤ X ├
#           ┌─┴─┐└───┘┌─┴─┐└───┘┌─┴─┐└───┘
# q_4: ─────┤ X ├─────┤ X ├─────┤ X ├─────
#           └───┘     └───┘     └───┘
# c: 5/═══════════════════════════════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = assemble(transpile(qc, simulator))
result = simulator.run(job).result()
statevector = result.get_statevector()

# Visualize the state vector of the circuit
print("\nFinal State Vector:")
print(statevector)
array_to_latex(statevector, prefix="\\text{Statevector = }")
# Out:
# Final State Vector:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))
# /var/folders/0s/wm9v8tmn6hl16w62yq_hh19h0000gn/T/ipykernel_35851/320873138.py:3: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = simulator.run(job).result()
# $$
# \text{Statevector = }
# \begin{bmatrix}
# 0 & 0 & 0 & 0 & \cdots & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
qc.measure(range(5), range(5))
backend = Aer.get_backend('qasm_simulator')
result = execute(qc, backend).result()

# Get the measurement result from the result object
counts = result.get_counts()

# Print the measurement result
print("\nMeasurement Result:")
print(counts)
# Out:
# Measurement Result:
# {'10101': 1024}
